# %%
import pyodide_js
await pyodide_js.loadPackage('numpy')
await pyodide_js.loadPackage('matplotlib')

# %%
import Parameters as p
import Functions as f

# %% [markdown]
# Setting parameters for Task A

# %%
periods = 1
nt_nondim = 100
mu = 2/3

f.plot(f.runge_kutta(periods, nt_nondim, mu), f.time_param(periods, nt_nondim)[2])
